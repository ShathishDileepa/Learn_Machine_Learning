# %% [markdown]
# # Types of Associative Learning Algorithms
#
# * Associative rule learning is basically coming up with patterns (or rules). It is said that these type of models are mostly used for __market basket problems__.
# * Its basically coming up with __"People who buys this, also buys.."__
#
# * So in this notebook we will be talking about two algorithms. That is,
#     1. Apriori Algorithm
#     2. Eclat Algorithm

# %% [markdown]
# ## 1. Apriori Algorithm
#
# As the name suggest it uses some prior knowledge to comeup with rules. That's what Apriori algorith does.This is a __Greedy Algorithm__ meaning that it will look through all the possible combinations of rules. And it will can culate `Confidence`, `Support` and `Lift`.
#
# * `Support(A,B) = Number of transactions contains A,B / Total Number of transactions`
#
# * `Confidence(A->B) = Number of transactions contains A,B / Total Number of transactions contains A`
#
# * `Lift(A->B) = Support(A,B) / Support(A) * Support(B)`
#
# * If the lift > 1 B is likely to pair together with A.
#
# * If the lift < 1 B is unlikely to pair together with A.
#
# Following article is really great, Try it if any confusion occurs :
# https://www.kdnuggets.com/2016/04/association-rules-apriori-algorithm-tutorial.html

# %% [markdown]
# <img  src="images/A_1.png"/>

# %%
# Okay now let's implement this

# importing the usual modules
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# uncomment and run this when you need or you can run this in mini conda terminal as well
#!pip install efficient-apriori
#!pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.2 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: pandas>=0.24.2 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (1.4.3)
# Requirement already satisfied: setuptools in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (63.4.1)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: scipy>=1.2.1 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: joblib>=0.13.2 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\learn and projects\ml learn projects\dummy_project\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0

# %%
# now for this we will be using a different module, so we have to install it by running the above cell
# from efficient_apriori import apriori # this thing is not working sooo #PS this also works

from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# The apriori function expects data in a one-hot encoded pandas DataFrame. So lets convert our dataset into that,
#
# read :
# https://github.com/rasbt/mlxtend/blob/master/docs/sources/user_guide/frequent_patterns/apriori.ipynb
# https://github.com/rasbt/mlxtend/blob/master/docs/sources/user_guide/frequent_patterns/association_rules.ipynb

# %%
# importing the dataset
data = pd.read_csv('data/Apriori/Market_Basket_Optimisation.csv',header=None)
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
data.shape
# Out:
# (7501, 20)

# %%
# now we cant use this as our input to our algorithm we have to reformat this to list that contains list of strings

# prepare the data

# list of transactions with NaN values
temp_arrays = data.iloc[:7501].to_numpy()

# Boolean arrays that helps filtering
bool_arrays = np.invert(data.iloc[:7501].isna().to_numpy())

def filter_transactions(messy_arrys,bool_arrys):
    """
    When same size array and a 2D boolean array is passed array is filtered using numpy array filtering
    """
    result =[]
    
    # if arrays are not of same length, cannot be done
    if len(messy_arrys) != len(bool_arrys):
        print('Arrays should be of same size')
        return
    else:
        for i in range(len(messy_arrys)):
            temp = messy_arrys[i]
            result.append(temp[bool_arrys[i]])
        return result

# clean transactions
transactions = filter_transactions(temp_arrays,bool_arrays)
transactions[1]
# Out:
# array(['burgers', 'meatballs', 'eggs'], dtype=object)

# %%
# this is for  understanding filtering path
arr = data.iloc[1:2].to_numpy().reshape(20,)

# %%
x = np.invert(data.iloc[1:2].isna().to_numpy().reshape(20,))
arr[x]
# Out:
# array(['burgers', 'meatballs', 'eggs'], dtype=object)

# %%
# now we can convert the dataset into the relavent format
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head().T
# Out:
#                        0      1      2      3      4
#  asparagus         False  False  False  False  False
# almonds             True  False  False  False  False
# antioxydant juice   True  False  False  False  False
# asparagus          False  False  False  False  False
# avocado             True  False  False   True  False
# ...                  ...    ...    ...    ...    ...
# whole wheat pasta  False  False  False  False  False
# whole wheat rice   False  False  False  False   True
# yams                True  False  False  False  False
# yogurt cake        False  False  False  False  False
# zucchini           False  False  False  False  False
#
# [120 rows x 5 columns]

# %%
# So how do we decide the minimum support
# We need to include products that atleast sold 3 times a day, 7 days a week
# so if we consider a item like that support would be (since this dataset contains list of items people bought over a week)
3*7/7500
# Out:
# 0.0028

# %%
# Now lets find the frequent items

frequent_itemsets = apriori(df,min_support=0.003,max_len=2,use_colnames=True)

frequent_itemsets
# Out:
#       support                      itemsets
# 0    0.020397                     (almonds)
# 1    0.008932           (antioxydant juice)
# 2    0.004666                   (asparagus)
# 3    0.033329                     (avocado)
# 4    0.004533                 (babies food)
# ..        ...                           ...
# 896  0.003200        (turkey, tomato juice)
# 897  0.006532            (tomatoes, turkey)
# 898  0.003200    (tomatoes, vegetables mix)
# 899  0.005999  (tomatoes, whole wheat rice)
# 900  0.007066    (turkey, whole wheat rice)
#
# [901 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules
# we can change the metrics and there minimum threshold and see
association_rules(frequent_itemsets, metric="lift", min_threshold=3.0)
# Out:
#                antecedents             consequents  antecedent support  \
# 0         (cottage cheese)              (brownies)            0.031862
# 1               (brownies)        (cottage cheese)            0.033729
# 2            (light cream)               (chicken)            0.015598
# 3                (chicken)           (light cream)            0.059992
# 4   (mushroom cream sauce)              (escalope)            0.019064
# 5               (escalope)  (mushroom cream sauce)            0.079323
# 6                  (pasta)              (escalope)            0.015731
# 7               (escalope)                 (pasta)            0.079323
# 8           (tomato juice)           (fresh bread)            0.030396
# 9            (fresh bread)          (tomato juice)            0.043061
# 10                 (honey)            (fresh tuna)            0.047460
# 11            (fresh tuna)                 (honey)            0.022264
# 12                 (honey)         (fromage blanc)            0.047460
# 13         (fromage blanc)                 (honey)            0.013598
# 14         (herb & pepper)           (ground beef)            0.049460
# 15           (ground beef)         (herb & pepper)            0.098254
# 16          (tomato sauce)           (ground beef)            0.014131
# 17           (ground beef)          (tomato sauce)            0.098254
# 18             (olive oil)           (light cream)            0.065858
# 19           (light cream)             (olive oil)            0.015598
# 20             (olive oil)     (whole wheat pasta)            0.065858
# 21     (whole wheat pasta)             (olive oil)            0.029463
# 22                 (pasta)                (shrimp)            0.015731
# 23                (shrimp)                 (pasta)            0.071457
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.033729  0.003466    0.108787  3.225330  0.002392    1.084220
# 1             0.031862  0.003466    0.102767  3.225330  0.002392    1.079026
# 2             0.059992  0.004533    0.290598  4.843951  0.003597    1.325072
# 3             0.015598  0.004533    0.075556  4.843951  0.003597    1.064858
# 4             0.079323  0.005733    0.300699  3.790833  0.004220    1.316568
# 5             0.019064  0.005733    0.072269  3.790833  0.004220    1.057349
# 6             0.079323  0.005866    0.372881  4.700812  0.004618    1.468107
# 7             0.015731  0.005866    0.073950  4.700812  0.004618    1.062867
# 8             0.043061  0.004266    0.140351  3.259356  0.002957    1.113174
# 9             0.030396  0.004266    0.099071  3.259356  0.002957    1.076227
# 10            0.022264  0.003999    0.084270  3.785070  0.002943    1.067712
# 11            0.047460  0.003999    0.179641  3.785070  0.002943    1.161125
# 12            0.013598  0.003333    0.070225  5.164271  0.002688    1.060903
# 13            0.047460  0.003333    0.245098  5.164271  0.002688    1.261806
# 14            0.098254  0.015998    0.323450  3.291994  0.011138    1.332860
# 15            0.049460  0.015998    0.162822  3.291994  0.011138    1.135410
# 16            0.098254  0.005333    0.377358  3.840659  0.003944    1.448259
# 17            0.014131  0.005333    0.054274  3.840659  0.003944    1.042446
# 18            0.015598  0.003200    0.048583  3.114710  0.002172    1.034669
# 19            0.065858  0.003200    0.205128  3.114710  0.002172    1.175211
# 20            0.029463  0.007999    0.121457  4.122410  0.006059    1.104713
# 21            0.065858  0.007999    0.271493  4.122410  0.006059    1.282270
# 22            0.071457  0.005066    0.322034  4.506672  0.003942    1.369601
# 23            0.015731  0.005066    0.070896  4.506672  0.003942    1.059374

# %%
# lets try this one too
from efficient_apriori import apriori

itemsets, rules = apriori(transactions, min_support=0.003,  min_confidence=0.2,max_length=2)
print(rules)
# Out:
# [{almonds} -> {burgers}, {almonds} -> {chocolate}, {almonds} -> {eggs}, {almonds} -> {french fries}, {almonds} -> {green tea}, {almonds} -> {milk}, {almonds} -> {mineral water}, {almonds} -> {spaghetti}, {avocado} -> {chocolate}, {avocado} -> {french fries}, {avocado} -> {milk}, {avocado} -> {mineral water}, {avocado} -> {spaghetti}, {bacon} -> {mineral water}, {bacon} -> {spaghetti}, {barbecue sauce} -> {eggs}, {barbecue sauce} -> {mineral water}, {black tea} -> {eggs}, {black tea} -> {milk}, {black tea} -> {mineral water}, {black tea} -> {spaghetti}, {blueberries} -> {mineral water}, {blueberries} -> {spaghetti}, {body spray} -> {french fries}, {body spray} -> {mineral water}, {brownies} -> {eggs}, {brownies} -> {french fries}, {brownies} -> {mineral water}, {brownies} -> {spaghetti}, {burgers} -> {eggs}, {burgers} -> {french fries}, {burgers} -> {green tea}, {ham} -> {burgers}, {burgers} -> {milk}, {burgers} -> {mineral water}, {burgers} -> {spaghetti}, {butter} -> {chocolate}, {butter} -> {eggs}, {butter} -> {french fries}, {butter} -> {green tea}, {butter} -> {milk}, {butter} -> {spaghetti}, {cake} -> {eggs}, {cake} -> {french fries}, {cake} -> {mineral water}, {cake} -> {spaghetti}, {carrots} -> {chocolate}, {carrots} -> {green tea}, {carrots} -> {mineral water}, {carrots} -> {spaghetti}, {cereals} -> {chocolate}, {cereals} -> {green tea}, {cereals} -> {milk}, {cereals} -> {mineral water}, {cereals} -> {spaghetti}, {champagne} -> {chocolate}, {chicken} -> {chocolate}, {chicken} -> {eggs}, {light cream} -> {chicken}, {chicken} -> {milk}, {chicken} -> {mineral water}, {chicken} -> {spaghetti}, {cooking oil} -> {chocolate}, {chocolate} -> {eggs}, {escalope} -> {chocolate}, {french fries} -> {chocolate}, {chocolate} -> {french fries}, {french wine} -> {chocolate}, {fresh bread} -> {chocolate}, {fresh tuna} -> {chocolate}, {fromage blanc} -> {chocolate}, {frozen smoothie} -> {chocolate}, {frozen vegetables} -> {chocolate}, {grated cheese} -> {chocolate}, {ground beef} -> {chocolate}, {ham} -> {chocolate}, {light cream} -> {chocolate}, {milk} -> {chocolate}, {mineral water} -> {chocolate}, {chocolate} -> {mineral water}, {mushroom cream sauce} -> {chocolate}, {oil} -> {chocolate}, {olive oil} -> {chocolate}, {pancakes} -> {chocolate}, {parmesan cheese} -> {chocolate}, {pepper} -> {chocolate}, {rice} -> {chocolate}, {salmon} -> {chocolate}, {shrimp} -> {chocolate}, {soup} -> {chocolate}, {spaghetti} -> {chocolate}, {chocolate} -> {spaghetti}, {tomato sauce} -> {chocolate}, {tomatoes} -> {chocolate}, {white wine} -> {chocolate}, {whole wheat pasta} -> {chocolate}, {whole wheat rice} -> {chocolate}, {cider} -> {eggs}, {cider} -> {milk}, {cooking oil} -> {eggs}, {cooking oil} -> {milk}, {cooking oil} -> {mineral water}, {cooking oil} -> {spaghetti}, {cottage cheese} -> {green tea}, {cottage cheese} -> {mineral water}, {cottage cheese} -> {spaghetti}, {eggplant} -> {eggs}, {eggplant} -> {mineral water}, {eggplant} -> {spaghetti}, {french fries} -> {eggs}, {eggs} -> {french fries}, {french wine} -> {eggs}, {fresh bread} -> {eggs}, {fresh tuna} -> {eggs}, {fromage blanc} -> {eggs}, {frozen vegetables} -> {eggs}, {ground beef} -> {eggs}, {ham} -> {eggs}, {herb & pepper} -> {eggs}, {light cream} -> {eggs}, {light mayo} -> {eggs}, {low fat yogurt} -> {eggs}, {meatballs} -> {eggs}, {milk} -> {eggs}, {mineral water} -> {eggs}, {eggs} -> {mineral water}, {pancakes} -> {eggs}, {parmesan cheese} -> {eggs}, {red wine} -> {eggs}, {spaghetti} -> {eggs}, {eggs} -> {spaghetti}, {turkey} -> {eggs}, {energy bar} -> {milk}, {energy bar} -> {mineral water}, {energy drink} -> {french fries}, {energy drink} -> {mineral water}, {escalope} -> {french fries}, {escalope} -> {mineral water}, {mushroom cream sauce} -> {escalope}, {pasta} -> {escalope}, {extra dark chocolate} -> {mineral water}, {extra dark chocolate} -> {spaghetti}, {flax seed} -> {green tea}, {fromage blanc} -> {french fries}, {frozen smoothie} -> {french fries}, {frozen vegetables} -> {fre ...

# %% [markdown]
# You can read about this algorithm in here : https://efficient-apriori.readthedocs.io/en/latest/#efficient_apriori.apriori
